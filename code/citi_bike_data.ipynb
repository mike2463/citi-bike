# %%
import pandas as pd
from pathlib import Path

# %%
#Read in 2019 data
jan_2019 = pd.read_csv(Path('../Resources/2019/jan_2019.csv'), parse_dates=True, infer_datetime_format=True)
feb_2019 = pd.read_csv(Path('../Resources/2019/feb_2019.csv'), parse_dates=True, infer_datetime_format=True)
mar_2019 = pd.read_csv(Path('../Resources/2019/mar_2019.csv'), parse_dates=True, infer_datetime_format=True)
apr_2019 = pd.read_csv(Path('../Resources/2019/apr_2019.csv'), parse_dates=True, infer_datetime_format=True)
may_2019 = pd.read_csv(Path('../Resources/2019/may_2019.csv'), parse_dates=True, infer_datetime_format=True)
june_2019 = pd.read_csv(Path('../Resources/2019/june_2019.csv'), parse_dates=True, infer_datetime_format=True)
july_2019 = pd.read_csv(Path('../Resources/2019/july_2019.csv'), parse_dates=True, infer_datetime_format=True)
aug_2019 = pd.read_csv(Path('../Resources/2019/aug_2019.csv'), parse_dates=True, infer_datetime_format=True)
sept_2019 = pd.read_csv(Path('../Resources/2019/sept_2019.csv'), parse_dates=True, infer_datetime_format=True)
oct_2019 = pd.read_csv(Path('../Resources/2019/oct_2019.csv'), parse_dates=True, infer_datetime_format=True)
nov_2019 = pd.read_csv(Path('../Resources/2019/nov_2019.csv'), parse_dates=True, infer_datetime_format=True)
dec_2019 = pd.read_csv(Path('../Resources/2019/dec_2019.csv'), parse_dates=True, infer_datetime_format=True)

# %%
jan_2019.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           320  2019-01-01 00:01:47.4010  2019-01-01 00:07:07.5810
# 1           316  2019-01-01 00:04:43.7360  2019-01-01 00:10:00.6080
# 2           591  2019-01-01 00:06:03.9970  2019-01-01 00:15:55.4380
# 3          2719  2019-01-01 00:07:03.5450  2019-01-01 00:52:22.6500
# 4           303  2019-01-01 00:07:35.9450  2019-01-01 00:12:39.5020
#
#    start station id           start station name  start station latitude  \
# 0            3160.0  Central Park West & W 76 St               40.778968
# 1             519.0        Pershing Square North               40.751873
# 2            3171.0      Amsterdam Ave & W 82 St               40.785247
# 3             504.0              1 Ave & E 16 St               40.732219
# 4             229.0               Great Jones St               40.727434
#
#    start station longitude  end station id        end station name  \
# ...

# %%
jan_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 967287 entries, 0 to 967286
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   tripduration             967287 non-null  int64
#  1   starttime                967287 non-null  object
#  2   stoptime                 967287 non-null  object
#  3   start station id         967269 non-null  float64
#  4   start station name       967269 non-null  object
#  5   start station latitude   967287 non-null  float64
#  6   start station longitude  967287 non-null  float64
#  7   end station id           967269 non-null  float64
#  8   end station name         967269 non-null  object
#  9   end station latitude     967287 non-null  float64
#  10  end station longitude    967287 non-null  float64
#  11  bikeid                   967287 non-null  int64
#  12  usertype                 967287 non-null  object
# ...

# %%
#Concatenate 2019 data
df_2019 = pd.concat([jan_2019, feb_2019, mar_2019, apr_2019, may_2019, june_2019, july_2019, aug_2019, sept_2019, oct_2019, nov_2019, dec_2019], ignore_index=True)

# %%
#View head
df_2019.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           320  2019-01-01 00:01:47.4010  2019-01-01 00:07:07.5810
# 1           316  2019-01-01 00:04:43.7360  2019-01-01 00:10:00.6080
# 2           591  2019-01-01 00:06:03.9970  2019-01-01 00:15:55.4380
# 3          2719  2019-01-01 00:07:03.5450  2019-01-01 00:52:22.6500
# 4           303  2019-01-01 00:07:35.9450  2019-01-01 00:12:39.5020
#
#    start station id           start station name  start station latitude  \
# 0            3160.0  Central Park West & W 76 St               40.778968
# 1             519.0        Pershing Square North               40.751873
# 2            3171.0      Amsterdam Ave & W 82 St               40.785247
# 3             504.0              1 Ave & E 16 St               40.732219
# 4             229.0               Great Jones St               40.727434
#
#    start station longitude  end station id        end station name  \
# ...

# %%
#View tail
df_2019.tail()
# Out:
#           tripduration                 starttime                  stoptime  \
# 20551692            93  2019-12-31 23:58:18.0160  2019-12-31 23:59:51.6360
# 20551693           786  2019-12-31 23:58:59.8960  2020-01-01 00:12:06.3460
# 20551694           351  2019-12-31 23:59:03.6950  2020-01-01 00:04:54.8730
# 20551695          1571  2019-12-31 23:59:21.3610  2020-01-01 00:25:32.9420
# 20551696           310  2019-12-31 23:59:55.2960  2020-01-01 00:05:05.7270
#
#           start station id                start station name  \
# 20551692            3141.0                   1 Ave & E 68 St
# 20551693             490.0                   8 Ave & W 33 St
# 20551694            3349.0  Grand Army Plaza & Plaza St West
# 20551695             252.0      MacDougal St & Washington Sq
# 20551696            3351.0                  E 102 St & 1 Ave
#
#           start station latitude  start station longitude  end station id  \
# ...

# %%
#len of 2019 data
len(df_2019)
# Out:
# 20551697

# %%
#Memory usage of 2019 data
df_2019.memory_usage(deep=True).sum()
# Out:
# 9492851699

# %%
#Read in 2020 data
jan_2020 = pd.read_csv(Path('../Resources/2020/jan_2020.csv'), parse_dates=True, infer_datetime_format=True)
feb_2020 = pd.read_csv(Path('../Resources/2020/feb_2020.csv'), parse_dates=True, infer_datetime_format=True)
mar_2020 = pd.read_csv(Path('../Resources/2020/mar_2020.csv'), parse_dates=True, infer_datetime_format=True)
apr_2020 = pd.read_csv(Path('../Resources/2020/apr_2020.csv'), parse_dates=True, infer_datetime_format=True)
may_2020 = pd.read_csv(Path('../Resources/2020/may_2020.csv'), parse_dates=True, infer_datetime_format=True)
june_2020 = pd.read_csv(Path('../Resources/2020/june_2020.csv'), parse_dates=True, infer_datetime_format=True)
july_2020 = pd.read_csv(Path('../Resources/2020/july_2020.csv'), parse_dates=True, infer_datetime_format=True)
aug_2020 = pd.read_csv(Path('../Resources/2020/aug_2020.csv'), parse_dates=True, infer_datetime_format=True)
sept_2020 = pd.read_csv(Path('../Resources/2020/sept_2020.csv'), parse_dates=True, infer_datetime_format=True)
oct_2020 = pd.read_csv(Path('../Resources/2020/oct_2020.csv'), parse_dates=True, infer_datetime_format=True)
nov_2020 = pd.read_csv(Path('../Resources/2020/nov_2020.csv'), parse_dates=True, infer_datetime_format=True)
dec_2020 = pd.read_csv(Path('../Resources/2020/dec_2020.csv'), parse_dates=True, infer_datetime_format=True)

# %%
#Concatenate 2020 data
df_2020 = pd.concat([jan_2020, feb_2020, mar_2020, apr_2020, may_2020, june_2020, july_2020, aug_2020, sept_2020, oct_2020, nov_2020, dec_2020], ignore_index=True)

# %%
#File size of 2020 data
df_2020.memory_usage(deep=True).sum()
# Out:
# 9019468289

# %%
jan_2021 = pd.read_csv(Path('../Resources/2021/jan_2021.csv'), parse_dates=True, infer_datetime_format=True)
feb_2021 = pd.read_csv(Path('../Resources/2021/feb_2021.csv'), parse_dates=True, infer_datetime_format=True)
mar_2021 = pd.read_csv(Path('../Resources/2021/mar_2021.csv'), parse_dates=True, infer_datetime_format=True)
apr_2021 = pd.read_csv(Path('../Resources/2021/apr_2021.csv'), parse_dates=True, infer_datetime_format=True)
may_2021 = pd.read_csv(Path('../Resources/2021/may_2021.csv'), parse_dates=True, infer_datetime_format=True)
june_2021 = pd.read_csv(Path('../Resources/2021/june_2021.csv'), parse_dates=True, infer_datetime_format=True)
july_2021 = pd.read_csv(Path('../Resources/2021/july_2021.csv'), parse_dates=True, infer_datetime_format=True)
aug_2021 = pd.read_csv(Path('../Resources/2021/aug_2021.csv'), parse_dates=True, infer_datetime_format=True)
sept_2021 = pd.read_csv(Path('../Resources/2021/sept_2021.csv'), parse_dates=True, infer_datetime_format=True)
oct_2021 = pd.read_csv(Path('../Resources/2021/oct_2021.csv'), parse_dates=True, infer_datetime_format=True)
nov_2021 = pd.read_csv(Path('../Resources/2021/nov_2021.csv'), parse_dates=True, infer_datetime_format=True)
dec_2021 = pd.read_csv(Path('../Resources/2021/dec_2021.csv'), parse_dates=True, infer_datetime_format=True)
# Out:
# C:\Users\micha\AppData\Local\Temp\ipykernel_14428\1650885154.py:2: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   feb_2021 = pd.read_csv(Path('../Resources/2021/feb_2021.csv'), parse_dates=True, infer_datetime_format=True)
# C:\Users\micha\AppData\Local\Temp\ipykernel_14428\1650885154.py:3: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   mar_2021 = pd.read_csv(Path('../Resources/2021/mar_2021.csv'), parse_dates=True, infer_datetime_format=True)
# C:\Users\micha\AppData\Local\Temp\ipykernel_14428\1650885154.py:4: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   apr_2021 = pd.read_csv(Path('../Resources/2021/apr_2021.csv'), parse_dates=True, infer_datetime_format=True)
# ...

# %%
feb_2021.head()
# Out:
#             ride_id rideable_type           started_at             ended_at  \
# 0  BBA33D73DECE976F   docked_bike  2021-02-26 16:38:54  2021-02-26 16:44:37
# 1  B63D7AFF9AC5B6D4   docked_bike  2021-02-17 11:09:11  2021-02-17 11:26:47
# 2  52B829195C469D99   docked_bike  2021-02-26 18:33:29  2021-02-26 19:05:41
# 3  19C84ECA2B468476   docked_bike  2021-02-26 12:48:35  2021-02-26 13:07:24
# 4  C0DDB771E70D9DF5   docked_bike  2021-02-25 17:23:22  2021-02-25 17:28:20
#
#         start_station_name start_station_id            end_station_name  \
# 0       E 84 St & Park Ave          7243.04             E 78 St & 2 Ave
# 1  Macon St & Nostrand Ave          4214.03         Bond St & Fulton St
# 2  Macon St & Nostrand Ave          4214.03  Lefferts Pl & Franklin Ave
# 3  Macon St & Nostrand Ave          4214.03         Bond St & Fulton St
# 4    Madison Ave & E 26 St          6131.12             W 37 St & 5 Ave
#
#   end_station_id  start_lat  start_lng    end_lat    end_lng member_casual
# ...

# %%
df_2021 = pd.concat([jan_2021, feb_2021, mar_2021, apr_2021, may_2021, june_2021, july_2021, aug_2021, sept_2021, oct_2021, nov_2021, dec_2021], ignore_index=True)

# %%
df_2021.memory_usage(deep=True).sum()
# Out:
# 23927022166

# %%
jan_2022 = pd.read_csv(Path('../Resources/2022/jan_2022.csv'), parse_dates=True, infer_datetime_format=True)
feb_2022 = pd.read_csv(Path('../Resources/2022/feb_2022.csv'), parse_dates=True, infer_datetime_format=True)
mar_2022 = pd.read_csv(Path('../Resources/2022/mar_2022.csv'), parse_dates=True, infer_datetime_format=True)
apr_2022 = pd.read_csv(Path('../Resources/2022/apr_2022.csv'), parse_dates=True, infer_datetime_format=True)
may_2022 = pd.read_csv(Path('../Resources/2022/may_2022.csv'), parse_dates=True, infer_datetime_format=True)
june_2022 = pd.read_csv(Path('../Resources/2022/june_2022.csv'), parse_dates=True, infer_datetime_format=True)
july_2022 = pd.read_csv(Path('../Resources/2022/july_2022.csv'), parse_dates=True, infer_datetime_format=True)
aug_2022 = pd.read_csv(Path('../Resources/2022/aug_2022.csv'), parse_dates=True, infer_datetime_format=True)
sept_2022 = pd.read_csv(Path('../Resources/2022/sept_2022.csv'), parse_dates=True, infer_datetime_format=True)
oct_2022 = pd.read_csv(Path('../Resources/2022/oct_2022.csv'), parse_dates=True, infer_datetime_format=True)
nov_2022 = pd.read_csv(Path('../Resources/2022/nov_2022.csv'), parse_dates=True, infer_datetime_format=True)
dec_2022 = pd.read_csv(Path('../Resources/2022/dec_2022.csv'), parse_dates=True, infer_datetime_format=True)
# Out:
# C:\Users\micha\AppData\Local\Temp\ipykernel_14428\2242411968.py:1: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   jan_2022 = pd.read_csv(Path('../Resources/2022/jan_2022.csv'), parse_dates=True, infer_datetime_format=True)
# C:\Users\micha\AppData\Local\Temp\ipykernel_14428\2242411968.py:2: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   feb_2022 = pd.read_csv(Path('../Resources/2022/feb_2022.csv'), parse_dates=True, infer_datetime_format=True)
# C:\Users\micha\AppData\Local\Temp\ipykernel_14428\2242411968.py:3: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   mar_2022 = pd.read_csv(Path('../Resources/2022/mar_2022.csv'), parse_dates=True, infer_datetime_format=True)
# ...

# %%
df_2022 = pd.concat([jan_2022, feb_2022, mar_2022, apr_2022, may_2022, june_2022, july_2022, aug_2022, sept_2022, oct_2022, nov_2022, dec_2022], ignore_index=True)

# %%
df_2022.memory_usage(deep=True).sum()
# Out:
# 19701005246

# %%
jan_2023 = pd.read_csv(Path('../Resources/2023/jan_2023.csv'), parse_dates=True, infer_datetime_format=True)
feb_2023 = pd.read_csv(Path('../Resources/2023/feb_2023.csv'), parse_dates=True, infer_datetime_format=True)
mar_2023 = pd.read_csv(Path('../Resources/2023/mar_2023.csv'), parse_dates=True, infer_datetime_format=True)
apr_2023 = pd.read_csv(Path('../Resources/2023/apr_2023.csv'), parse_dates=True, infer_datetime_format=True)
may_2023 = pd.read_csv(Path('../Resources/2023/may_2023.csv'), parse_dates=True, infer_datetime_format=True)
# Out:
# C:\Users\micha\AppData\Local\Temp\ipykernel_14428\2482064256.py:1: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   jan_2023 = pd.read_csv(Path('../Resources/2023/jan_2023.csv'), parse_dates=True, infer_datetime_format=True)
# C:\Users\micha\AppData\Local\Temp\ipykernel_14428\2482064256.py:2: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   feb_2023 = pd.read_csv(Path('../Resources/2023/feb_2023.csv'), parse_dates=True, infer_datetime_format=True)
# C:\Users\micha\AppData\Local\Temp\ipykernel_14428\2482064256.py:3: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   mar_2023 = pd.read_csv(Path('../Resources/2023/mar_2023.csv'), parse_dates=True, infer_datetime_format=True)
# ...

# %%
df_2023 = pd.concat([jan_2023, feb_2023, mar_2023, apr_2023, may_2023], ignore_index=True)

# %%
df_2023.memory_usage(deep=True).sum()
# Out:
# 7783167816
